# %%
## Assignment 47 - 24 March 2023 Divya

# %% [markdown]
# **Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine ?**

# %% [markdown]
# ### Key Features:
#
# Fixed Acidity: This refers to the amount of non-volatile acids in the wine. These acids contribute to the overall acidity of the wine and can affect its taste and preservation.
#
# Volatile Acidity: Volatile acids are those that can easily evaporate and contribute to the smell of vinegar. High levels of volatile acidity can lead to off-putting aromas and flavors in wine.
#
# Citric Acid: Citric acid is a natural component found in grapes and is often added during winemaking to enhance acidity and flavor balance.
#
# Residual Sugar: This is the amount of sugar remaining in the wine after fermentation. It affects the sweetness of the wine and can influence the overall taste profile.
#
# Chlorides: Chlorides are salts that can impact the wine's flavor and balance. Higher levels can contribute to a salty taste.
#
# Free Sulfur Dioxide: Sulfur dioxide is used as a preservative in winemaking. The free form is the active form that can prevent oxidation and microbial growth.
#
# Total Sulfur Dioxide: This includes both the free and bound forms of sulfur dioxide. Total sulfur dioxide levels impact the wine's stability and shelf life.
#
# Density: Density is a measure of the wine's mass relative to its volume. It can be used as an indicator of the wine's alcohol content.
#
# pH: pH indicates the wine's acidity level. Proper pH is important for the stability and microbial safety of the wine.
#
# Sulphates: Sulphates, or sulfites, are compounds that are also used as preservatives in winemaking. They can impact the wine's flavor and aroma.
#
# Alcohol: The alcohol content of the wine can influence its body, mouthfeel, and overall perception of quality.
#
# ### Importance of Each Feature:
#
# Each of these features plays a crucial role in determining the overall quality and characteristics of a wine. Winemaking is a complex process where chemical composition directly affects the taste, aroma, and overall enjoyment of the wine. For instance:
#
# Acidity: Acidity levels influence the wine's freshness, balance, and potential for aging. Too much acidity can make a wine taste sour, while too little can result in a flat taste.
#
# Sugar: Residual sugar affects the sweetness and perceived body of the wine. Balancing sugar levels is important to achieve the desired flavor profile.
#
# Sulfur Compounds: Sulfur compounds, like free and total sulfur dioxide, are crucial for preserving wine and preventing spoilage. They also play a role in the wine's aroma and taste.
#
# Alcohol: Alcohol content impacts the wine's viscosity, body, and warmth. It also contributes to the wine's overall balance.
#
# pH and Density: These features are related to acidity and alcohol content, respectively, and impact the overall mouthfeel and stability of the wine.

# %% [markdown]
# **Q2. How did you handle missing data in the wine quality data set during the feature engineering process? Discuss the advantages and disadvantages of different imputation techniques.**

# %% [markdown]
# The different types os Imputation techniques are :
#
# 1. Mean/Median Imputation:
# <br>Advantages: Simple and quick to implement. Does not distort the distribution of the variable significantly.
# <br>Disadvantages: Ignores the relationships between variables, potentially leading to biased results. Can underestimate the variability of the imputed values.
#
# 2. Mode Imputation (for categorical data):
# <br>Advantages: Simple and appropriate for categorical variables. Does not introduce new values.
# <br>Disadvantages: Similar to mean/median imputation, it does not consider relationships between variables.
#
# 3. Linear Regression Imputation:
# <br>Advantages: Takes into account relationships between variables, making it more accurate than simple imputation methods.
# <br>Disadvantages: Assumes a linear relationship between variables. May not be suitable for non-linear relationships.
#
# 4. K-Nearest Neighbors (KNN) Imputation:
# <br>Advantages: Considers relationships among variables. Can capture non-linear patterns. Can work well for datasets with complex relationships.
# <br>Disadvantages: Computationally more intensive, especially for large datasets. The choice of K (number of neighbors) can impact results.
#
# 5. Multiple Imputation:
# <br>Advantages: Generates multiple imputed datasets, accounting for uncertainty due to missing values. Provides more accurate estimates and standard errors.
# <br>Disadvantages: Requires multiple model fitting. Can be computationally expensive and complex to implement.
#
# 6. Domain-Specific Imputation:
# <br>Advantages: Utilizes domain knowledge to make informed imputation decisions. Can lead to more accurate results.
# <br>Disadvantages: Requires expertise in the domain. Might not always be feasible if domain knowledge is limited.
#
# 7. Imputation Using Machine Learning Algorithms:
# <br>Advantages: Can capture complex relationships and interactions in the data. Flexible and robust.
# <br>Disadvantages: Requires training a model for imputation, which might introduce additional complexity.

# %%
import pandas as pd
df = pd.read_csv("winequality-red.csv")
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### So here there is no missing value in this Wine Quality dataset but if there were any we could use the above techiques to solve this

# %% [markdown]
# **Q3. What are the key factors that affect students' performance in exams? How would you go about analyzing these factors using statistical techniques?**

# %% [markdown]
# The key factors are :
# - gender : sex of students  -> (Male/female)
# - race/ethnicity : ethnicity of students -> (Group A, B,C, D,E)
# - parental level of education : parents' final education ->(bachelor's degree,some college,master's degree,associate's degree,high school)
# - lunch : having lunch before test (standard or free/reduced)
# - test preparation course : complete or not complete before test
# - math score
# - reading score
# - writing score
#
# For using Statistical Analysis :
#
# 1. Check for missing values
# 2. Check for the duplicates
# 3. Check the data type
# 4. Check the unique values of each dataset
# 5. Convert the categorical variables to numeric
# 6. Perform statistic analysis on the numeric values
#
# **The most important features can be selected with the help of finding the correlation between the variables**

# %% [markdown]
# **Q4. Describe the process of feature engineering in the context of the student performance data set. How did you select and transform the variables for your model?**

# %% [markdown]
# 1. Data Exploration and Understanding:
# <br>Familiarize yourself with the dataset, its structure, and variable types.
# Identify the target variable ("math score," "reading score," "writing score") and the predictor variables ("gender," "race/ethnicity," "parental level of education," "lunch," "test preparation course").
#
# 2. Data Cleaning:
# <br>Handle missing values: Impute missing values using suitable methods. For categorical attributes, use mode imputation. For numerical scores, consider median imputation.
# Check for and handle any duplicate records.
#
# 3. Feature Selection:
# <br>Retain all the provided attributes as they are all relevant to the project's objective.
#
# 4. Categorical Variable Encoding:
# <br>Convert categorical attributes to numerical representations using appropriate encoding methods.
# Use one-hot encoding for "gender," "race/ethnicity," and "parental level of education."
# For "lunch" and "test preparation course," encode them as binary variables (0 or 1) using label encoding.
#
# 5. Creating New Features:
# <br>Create a new feature like "total_exam_score" by summing up the scores in "math," "reading," and "writing." This could provide an overall view of a student's academic performance.
#
# 6. Feature Transformation:
# <br>No specific transformations may be necessary for this scenario as the attributes are already numerical.
#
# 7. Feature Scaling:
# <br>Since the exam scores are already on a common scale, scaling might not be necessary.
#
# 8. Outlier Handling:
# <br>Identify and handle outliers that could impact model performance, particularly in the exam scores. Use techniques like Z-score or IQR-based methods.
#
# 9. Feature Importance Analysis:
# <br>Train an initial model and analyze feature importances. This can help identify attributes with significant influence on the exam scores.
#
# 10. Model Training and Evaluation:
# <br>Split the dataset into training and testing sets.
# Train a regression model (e.g., Linear Regression, Random Forest) using the engineered features.
# Evaluate the model's performance on the testing data using appropriate metrics.
#
# 11. Iteration and Fine-Tuning:
# <br>Based on model performance, iterate on feature engineering. Experiment with interactions, polynomial features, or domain-specific transformations to enhance model accuracy.

# %% [markdown]
# **Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to these features to improve normality?**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Calculate skewness and kurtosis for each feature
skewness = df.skew()
kurtosis = df.kurtosis()

print("Skewness:")
print(skewness)

print("\nKurtosis:")
print(kurtosis)
# Out:
# Skewness:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64
#
# Kurtosis:
# fixed acidity            1.132143
# volatile acidity         1.225542
# citric acid             -0.788998
# residual sugar          28.617595
# chlorides               41.715787
# free sulfur dioxide      2.023562
# total sulfur dioxide     3.809824
# density                  0.934079
# pH                       0.806943
# sulphates               11.720251
# alcohol                  0.200029
# quality                  0.296708
# dtype: float64

# %% [markdown]
# ### Skewness:
# Skewness measures the degree of asymmetry in a distribution.
#
# Positive Skewness (Right Skewed): If skewness > 0
# - The tail on the right side is longer or fatter than the left side.
# - Most of the data is concentrated on the left side.
# - The mean is typically greater than the median.
#
# Negative Skewness (Left Skewed): If skewness < 0
# - The tail on the left side is longer or fatter than the right side.
# - Most of the data is concentrated on the right side.
# - The mean is typically less than the median.
#
# Zero Skewness (Symmetric): If skewness ≈ 0
# - The data is evenly distributed around the mean.
# - The left and right sides of the distribution are balanced.
#
#
# ### Kurtosis:
# Kurtosis measures the tails' heaviness or lightness compared to a normal distribution.
#
# Leptokurtic (Positive Kurtosis): If kurtosis > 3
# - The distribution has heavier tails and a sharper peak than a normal distribution.
# It may have more extreme values (outliers) compared to a normal distribution.
#
# Mesokurtic (Normal Kurtosis): If kurtosis ≈ 3
# - The distribution's tails and peak are similar to a normal distribution.
# - It indicates the data has a similar spread and tail behavior as a normal distribution.
#
# Platykurtic (Negative Kurtosis): If kurtosis < 3
# - The distribution has lighter tails and a flatter peak compared to a normal distribution.
# - It is less prone to outliers and has a wider, more uniform shape.

# %% [markdown]
# ### Observation:
# - All the data is positively skewed
# - fixed acidity,volatile acidity,citric acid,free sulfur dioxide,density,pH,alcohol,quality are Platykurtic/Negative Kurtosis
# - residual sugar,chlorides,total sulfur dioxide and sulphates are LaptoKurtic/Positive kurtosis

# %%
plt.figure(figsize=(20,15))
for i,col in enumerate(list(df.columns.values)):
    plt.subplot(4,3,i+1)
    sns.histplot(df[col],color='b',kde=True)
    plt.grid()
    plt.tight_layout()
# Out:
# C:\Users\divya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# 1. Fixed Acidity:
# - Positive skewness and moderately high kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 2. Volatile Acidity:
# - Positive skewness and moderately high kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 3. Citric Acid:
# - Positive skewness and negative kurtosis.
# - Since the kurtosis is already negative, focus on reducing skewness. Apply a power transformation (e.g., square root) to reduce skewness.
#
# 4. Residual Sugar:
# - Positive skewness and high kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 5. Chlorides:
# - Positive skewness and high kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 6. Free Sulfur Dioxide:
# - Positive skewness and moderately high kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 7. Total Sulfur Dioxide:
# - Positive skewness and moderately high kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 8. Density:
# - Positive skewness and moderate kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 9. pH:
# - Positive skewness and moderately high kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 10. Sulphates:
# - Positive skewness and high kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 11. Alcohol:
# - Positive skewness and low kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.
#
# 12. Quality:
# - Positive skewness and moderate kurtosis.
# - Apply a Box-Cox transformation to bring skewness closer to zero.

# %% [markdown]
# Different types of Tranformations are:
#
# 1. Log Transformation:
# <br>Formula: log(x) or log(x + c) where c is a constant to handle zero or negative values.
# <br>Effect: Reduces right-skewness, making the distribution more symmetric. Useful when data spans several orders of magnitude.
#
# 2. Square Root Transformation:
# <br>Formula: √(x) or √(x + c) where c is a constant to handle zero or negative values.
# <br>Effect: Similar to the log transformation, it reduces right-skewness and can make the distribution more symmetric.
#
# 3. Box-Cox Transformation:
# <br>Formula: T(x) = [(x^λ) - 1] / λ for positive values of x. For negative values or zero, use a modification.
# <br>Effect: The Box-Cox transformation is a family of power transformations that can handle various levels of skewness. The parameter λ is chosen to maximize normality. Requires data to be strictly positive.
#
# 4. Inverse Transformation:
# <br>Formula: 1 / x or 1 / (x + c) where c is a constant to handle zero values.
# <br>Effect: Can be useful for left-skewed data, as it transforms larger values closer to zero.
#
# 5. Power Transformation:
# <br>Formula: (x^λ) or (x + c)^λ where c is a constant to handle zero or negative values.
# <br>Effect: Allows for more flexibility than the above transformations, as you can adjust the power parameter λ to achieve the desired effect.
#
# 6. Rank Transformation:
# <br>Effect: Transforms data into ranks, which can help in handling extreme values and reducing the impact of outliers. <br>Especially useful for data with heavy tails.

# %% [markdown]
# **Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of features. What is the minimum number of principal components required to explain 90% of the variance in the data?**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('winequality-red.csv')

# Separate the features and target
X = data.drop('quality', axis=1)
y = data['quality']

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Plot explained variance ratio
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio.cumsum(), marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Principal Components')
plt.grid(True)
plt.show()

# Find the minimum number of principal components to explain 90% of the variance
cumulative_variance = explained_variance_ratio.cumsum()
min_components = len(cumulative_variance[cumulative_variance < 0.90]) + 1

print(f"Minimum number of principal components to explain 90% of the variance: {min_components}")
# Out:
# Minimum number of principal components to explain 90% of the variance: 7
